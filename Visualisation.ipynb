# %%
import matplotlib.pyplot as plt

# %%
x= [0, 6]
y = [0, 250]
plt.plot(x, y)
plt.show()

# %% [markdown]
# Draw the relationship

# %%
Month =["Jan", 'Feb',]

# %%
x=[2023, 2022, 2020, 2015, 2010, 2005, 2000, 1995]
y=[4644384, 4576298, 4543399, 4143580, 57698323,23166778, 234577,2589289]

# %%
plt.plot(x,y)
